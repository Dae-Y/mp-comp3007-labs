# %% [markdown]
# **Warm-Up Exercise: Google Colab, Python Libraries, Plotting, and Basic Programming**
#
# **Introduction**
#
# This practical exercise is designed to help students become familiar with Google Colab, install Python software libraries, perform plotting, and practice basic Python programming skills, including object-oriented programming. By the end of this exercise, students will have gained hands-on experience with the following:
# *   Using Google Colab for writing and executing Python code
# *   Installing and using common Python libraries
# *   Performing basic plotting with matplotlib
# *   Writing and testing simple Python functions
# *   Understanding and implementing basic object-oriented programming concepts
# *   Basic image processing techniques
# *   Creating a perception pipeline using object-oriented programming

# %% [markdown]
# **Step 1: Getting Started with Google Colab**
#
# Google Colab is an online platform that allows you to write and execute Python code in your browser, with access to powerful computational resources. Follow these steps to get started:
#
# *  Open your browser and go to Google Colab.
# *  Sign in with your Google account.
# *  Click on "New Notebook" to create a new Colab notebook.

# %% [markdown]
# **Step 2: Install Python Libraries**
# In this step, we will install some commonly used Python libraries, including numpy for numerical computations, matplotlib for plotting, and Pillow for image processing.

# %%
# Install requried libaries for the exercises in this practical
# !pip install numpy matplotlib pillow scikit-image

# %% [markdown]
# **Exercise 1: Simple Function**
# Write a function add_numbers(a, b) that takes two numbers as arguments and returns their sum. This exercise helps you practice writing and testing simple functions in Python.

# %%
# Function to add two numbers
def add_numbers(a, b):
    # Add your implementation below

# Test the function
result = add_numbers(3, 5)
print("The sum of 3 and 5 is:", result)
# Out:
# The sum of 3 and 5 is: 8

# %% [markdown]
# **Exercise 2: Object-Oriented Programming**
# Create a class Point that represents a point in 2D space. The class should have the following methods:
# *  `__init__(self, x, y):` Initializes a point with coordinates x and y.
# *  `move(self, dx, dy):` Moves the point by dx along the x-axis and dy along the y-axis.
# *  `__str__(self)`: Returns a string representation of the point.
# This exercise introduces basic object-oriented programming concepts.

# %%
# Class to represent a point in 2D space
class Point:
    def __init__(self, x, y):
        # Add your implementation below

    def move(self, dx, dy):
        # Add your implementation below

    def __str__(self):
        return f"Point({self.x}, {self.y})"

# Test the class
p = Point(2, 3)
print(p)
p.move(1, -1)
print(p)
# Out:
# Point(2, 3)
# Point(3, 2)

# %% [markdown]
# **Step 4: Plotting with Matplotlib**
# In this step, we will create a simple plot using matplotlib. We will plot a sine wave and a cosine wave on the same graph. This exercise demonstrates how to use matplotlib for basic plotting tasks.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate data


# Create the plot

# %% [markdown]
# **Step 5: Image Processing with Pillow**
# In this step, we will read an image, perform histogram equalization, and plot the image before and after processing.

# %%
from PIL import Image, ImageOps
import matplotlib.pyplot as plt

# Load the image

# Perform histogram equalization


# Plot the original and equalized images
# Out:
# --2024-07-01 13:08:21--  https://s30991.pcdn.co/about/wp-content/uploads/sites/5/2023/02/computer-lab-aspect-ratio-2-1.jpg
# Resolving s30991.pcdn.co (s30991.pcdn.co)... 18.160.41.3, 18.160.41.41, 18.160.41.102, ...
# Connecting to s30991.pcdn.co (s30991.pcdn.co)|18.160.41.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 139032 (136K) [image/jpeg]
# Saving to: ‘image.jpg’
#
# image.jpg           100%[===================>] 135.77K  --.-KB/s    in 0.009s
#
# 2024-07-01 13:08:21 (14.9 MB/s) - ‘image.jpg’ saved [139032/139032]

# %% [markdown]
# **Step 6: Perception Pipeline Using Object-Oriented Programming**
#
# In this step, we will create a simple perception pipeline using object-oriented programming. The pipeline will include the following blocks:
# *  Input block: Read an image that consists of a rectangle or circle.
# *  Image processing block: Perform filtering (image smoothing).
# *  Feature extraction block: Perform corner detection.
# *  Recognition block: Perform simple recognition using decision trees based on the number of corners.

# %%
import numpy as np
from skimage import io, filters, feature, color, transform
from skimage.feature import corner_harris, corner_subpix
from skimage.feature import corner_shi_tomasi, corner_peaks
from sklearn.tree import DecisionTreeClassifier

# Input block: Read an image
class InputBlock:
    def __init__(self, image_path):
        # Add your implementation below

    def get_image(self):
        return self.image

# Image processing block: Convert to grayscale
class ImageProcessingBlock:
    def __init__(self, image):
        # Add your implementation below

    def convert_to_grayscale(self):
        # Add your implementation below

# Feature extraction block: Perform corner detection
class FeatureExtractionBlock:
    def __init__(self, image):
        # Add your implementation below

    def detect_corners(self):
        # Add your implementation below

# Recognition block: Perform simple recognition
class RecognitionBlock:
    def __init__(self, coords):
        # Add your implementation below

    def recognize_shape(self):
        # Add your implementation below

# Create and test the perception pipeline
image_path = '00_square.png'  # square class
#image_path = '00_triangle.png' # triangle class
#image_path = '00_circle.png' # circle class

# Input block
input_block = InputBlock(image_path)
image = input_block.get_image()

# Image processing block
processing_block = ImageProcessingBlock(image)
grayscale_image = processing_block.convert_to_grayscale()

# Feature extraction block
extraction_block = FeatureExtractionBlock(grayscale_image)
corners = extraction_block.detect_corners()

# Recognition block
recognition_block = RecognitionBlock(corners)
shape = recognition_block.recognize_shape()
print("The recognized shape is:", shape)

# Plot the results
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
ax.imshow(grayscale_image, cmap='gray')
ax.plot(corners[:, 1], corners[:, 0], 'r.')
ax.set_title(f'Recognized Shape: {shape}')
ax.axis('off')
plt.show()
# Out:
# The recognized shape is: circle

# %% [markdown]
# **Summary of Learning Outcomes**
# By completing this exercise, students will have:
#
# *  Learned how to set up and use Google Colab for Python programming
# *  Installed and used essential Python libraries for numerical computations, plotting, and image processing
# *  Gained experience in writing and testing simple Python functions
# *  Understood and implemented basic object-oriented programming concepts through practical examples
# *  Performed basic image processing tasks such as histogram equalization and rotation
# *  Created a simple perception pipeline using object-oriented programming, incorporating image processing, feature extraction, and recognition blocks
# *  Used the Harris corner detection method to reduce false positives in feature extraction
# *  Implemented a method to convert color images to grayscale
# This exercise serves as a foundational practice for more advanced topics in Python programming, data analysis, and image processing.
